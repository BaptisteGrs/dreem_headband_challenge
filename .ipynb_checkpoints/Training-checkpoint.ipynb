# %% [markdown]
# #### Dreem Challenge

# %% [markdown]
# # Cleaning the dataset and Model training

# %%
# %run tool_factory
setup_environment()

from imports import *
from features import *
# Out:
# Setup environment... done!

# %%
x_train = pd.read_csv('../datasets/x_train_2812.csv')
x_test = pd.read_csv('../datasets/x_test_2812.csv')

# %%
train_labels = pd.read_csv('../dreem-sleep-stages-2020/y_train.csv')

# %%
print('The training set consists of {} instances with {} different features.'.format(x_train.shape[0], x_train.shape[1]))
print('The test set consists of {} instances with {} different features.'.format(x_test.shape[0], x_test.shape[1]))
# Out:
# The training set consists of 24688 instances with 170 different features.
# The test set consists of 24980 instances with 170 different features.

# %%
x_train.head()
# Out:
#    eeg_1_abs_mean  eeg_1_abs_median      eeg_1_std  eeg_1_abs_min  \
# 0        1.432455          2.341661  169305.421875   2.379453e+06
# 1       58.027500         11.648855  157490.359375   5.940831e+05
# 2       59.387001          4.925843     700.126648   6.725495e+03
# 3        2.419667          8.996914   83296.250000   2.800150e+05
# 4        3.366293          0.920760     686.976746   2.830944e+03
#
#    eeg_1_abs_max  eeg_1_fd_petrosian  eeg_1_app_entropy  eeg_1_higuchi_fd  \
# 0   5.310244e+05            1.021206           0.011610          1.289816
# 1   1.506996e+06            1.016912           0.066181          1.039523
# 2   3.700153e+03            1.019566           0.245238          1.395828
# 3   4.732804e+05            1.012796           0.081800          1.028449
# 4   4.614053e+03            1.017978           0.310973          1.295833
#
#    eeg_1_max_freq  eeg_1_max_spectrum  eeg_1_sum_spectrum  eeg_1_sum_delta  \
# 0        0.400000        3.276084e+10        8.599298e+11     4.989240e+11
# 1        0.333333        5.814520e+10        7.440963e+11     3.903176e+11
# 2        0.433333        1.184894e+06        1.470532e+07     8.128856e+06
# 3        0.366667        2.477588e+10        2.081480e+11     5.527722e+10
# 4        0.666667        1.424326e+06        1.415811e+07     9.470913e+06
#
#    eeg_1_sum_theta  eeg_1_sum_alpha  eeg_1_sum_beta  eeg_2_abs_mean  \
# 0     4.051503e+10     1.342091e+10    1.117625e+10        4.144058
# 1     2.609754e+09     2.185480e+07    2.339831e+06       42.037083
# 2     5.334419e+05     2.375662e+05    2.023538e+05       26.924881
# 3     1.102241e+08     2.226999e+06    3.013461e+05     5630.203125
# 4     4.246195e+05     7.723502e+04    3.288214e+04     5629.497559
#
#    eeg_2_abs_median      eeg_2_std  eeg_2_abs_min  eeg_2_abs_max  \
# 0          4.805282   50643.941406  714449.312500   1.556080e+05
# 1        240.261230  159468.140625  456643.718750   1.203993e+06
# 2         61.710052   81614.171875  436591.718750   4.262270e+05
# 3         18.542311   34435.695312  241527.953125   1.117863e+04
# 4        256.492157  241009.390625  540883.437500   1.279754e+06
#
#    eeg_2_fd_petrosian  eeg_2_app_entropy  eeg_2_higuchi_fd  eeg_2_max_freq  \
# 0            1.014966           0.013708          1.289043        0.433333
# 1            1.004005           0.128588          1.036675        0.400000
# 2            1.007892           0.073932          1.060168        0.466667
# 3            1.008834           0.022967          1.116781        0.233333
# 4            1.004860           0.182655          1.030895        0.300000
#
#    eeg_2_max_spectrum  eeg_2_sum_spectrum  eeg_2_sum_delta  eeg_2_sum_theta  \
# 0        2.867728e+09        7.694426e+10     4.483960e+10     3.652324e+09
# 1        1.112816e+11        7.629026e+11     1.862961e+11     6.986792e+08
# 2        1.850550e+10        1.998262e+11     1.338824e+11     3.093608e+08
# 3        2.038934e+09        3.557451e+10     1.081865e+10     3.380258e+08
# 4        2.520945e+11        1.742566e+12     7.703702e+11     1.395125e+09
#
#    eeg_2_sum_alpha  eeg_2_sum_beta  eeg_3_abs_mean  eeg_3_abs_median  \
# 0     1.209686e+09    1.006956e+09        3.688038          4.533875
# 1     4.410740e+07    4.198190e+06       43.494793        240.971619
# 2     1.049266e+07    2.352923e+06       26.024563         32.656090
# 3     1.215855e+08    1.661462e+08     5622.773926         45.552933
# 4     1.862193e+08    1.782337e+08     5600.155762         20.119667
#
#        eeg_3_std  eeg_3_abs_min  eeg_3_abs_max  eeg_3_fd_petrosian  \
# 0   48046.421875   1.474910e+05  677935.687500            1.015774
# 1  158512.000000   1.196118e+06  457091.562500            1.004361
# 2   82086.375000   4.319169e+05  436959.375000            1.010048
# 3   34289.480469   6.450457e+03  241150.671875            1.010670
# 4  241145.796875   1.276454e+06  541042.250000            1.005215
#
#    eeg_3_app_entropy  eeg_3_higuchi_fd  eeg_3_max_freq  eeg_3_max_spectrum  \
# 0           0.013660          1.289559        0.433333        2.579941e+09
# 1           0.127042          1.038670        0.400000        1.100312e+11
# 2           0.069659          1.058666        0.466667        1.802880e+10
# 3           0.005529          1.059044        0.066667        1.914675e+09
# 4           0.183549          1.031439        0.300000        2.517157e+11
#
#    eeg_3_sum_spectrum  eeg_3_sum_delta  eeg_3_sum_theta  eeg_3_sum_alpha  \
# 0        6.925377e+10     4.036852e+10     3.288629e+09     1.089263e+09
# 1        7.537818e+11     1.816813e+11     7.357789e+08     4.552500e+07
# 2        2.021452e+11     1.369116e+11     2.866612e+08     9.047825e+06
# 3        3.527305e+10     1.053554e+10     3.350940e+08     1.186454e+08
# 4        1.744539e+12     7.693835e+11     1.325527e+09     1.884257e+08
#
#    eeg_3_sum_beta  eeg_4_abs_mean  eeg_4_abs_median      eeg_4_std  \
# 0     906782976.0        5.865755         12.464251  119521.507812
# 1       4214938.0       17.821562        109.162849  228998.265625
# 2       2048553.0       29.919943         56.721039   81769.757812
# 3     165385424.0     5612.617188         42.277718   89581.539062
# 4     176132752.0     5608.957520        110.116974  240690.734375
#
#    eeg_4_abs_min  eeg_4_abs_max  eeg_4_fd_petrosian  eeg_4_app_entropy  \
# 0   3.781040e+05   1.677005e+06            1.013918           0.011278
# 1   1.709646e+06   1.201192e+06            1.004076           0.098797
# 2   4.354439e+05   4.342840e+05            1.011702           0.070246
# 3   4.668823e+05   2.770806e+05            1.011152           0.091374
# 4   5.399412e+05   1.275102e+06            1.007647           0.181184
#
#    eeg_4_higuchi_fd  eeg_4_max_freq  eeg_4_max_spectrum  eeg_4_sum_spectrum  \
# 0          1.287260        0.400000        1.667061e+10        4.285618e+11
# 1          1.048220        0.366667        1.851614e+11        1.573206e+12
# 2          1.058251        0.466667        1.776957e+10        2.005888e+11
# 3          1.022988        0.400000        3.382487e+10        2.407455e+11
# 4          1.030782        0.300000        2.505402e+11        1.737961e+12
#
#    eeg_4_sum_delta  eeg_4_sum_theta  eeg_4_sum_alpha  eeg_4_sum_beta  \
# 0     2.481729e+11     2.012583e+10     6.667146e+09    5.552953e+09
# 1     4.258203e+11     3.350943e+09     6.542078e+07    5.650478e+06
# 2     1.361481e+11     2.875334e+08     1.051165e+07    1.865265e+06
# 3     6.545669e+10     4.364689e+08     1.209026e+08    1.657520e+08
# 4     7.665807e+11     1.339145e+09     1.855840e+08    1.758856e+08
#
#    eeg_5_abs_mean  eeg_5_abs_median    eeg_5_std  eeg_5_abs_min  \
# 0        0.745618          2.955460  1744.949341   24512.250000
# 1        3.285713          6.796757  1601.447266   11786.343750
# 2        3.442591          5.074059   753.671570    2995.569092
# 3        7.736346         12.251701   633.202332    3819.203369
# 4       12.167157         22.826813   885.976135    3767.343750
#
#    eeg_5_abs_max  eeg_5_fd_petrosian  eeg_5_app_entropy  eeg_5_higuchi_fd  \
# 0    5442.656250            1.020355           0.015409          1.331191
# 1   12498.500000            1.015841           0.165753          1.121744
# 2    4996.125000            1.017079           0.240209          1.323870
# 3    5136.226074            1.015067           0.253757          1.409016
# 4    4103.863770            1.013171           0.592141          1.345188
#
#    eeg_5_max_freq  eeg_5_max_spectrum  eeg_5_sum_spectrum  eeg_5_sum_delta  \
# 0        0.400000        3.571580e+06          91345440.0       52822676.0
# 1        0.700000        3.632516e+06          76939000.0       57464092.0
# 2        0.466667        1.200804e+06          17040624.0        9973570.0
# 3        0.600000        4.069337e+05          12028356.0        8719139.0
# 4        0.633333        3.390289e+06          23548608.0       15180089.0
#
#    eeg_5_sum_theta  eeg_5_sum_alpha  eeg_5_sum_beta  eeg_6_abs_mean  \
# 0      4295542.000     1.421974e+06    1.181761e+06        0.456145
# 1      1168011.875     1.032972e+05    2.429565e+04        1.456490
# 2       516661.875     1.481072e+05    4.027442e+04        0.899961
# 3      1928836.625     2.369973e+05    7.296612e+04        7.430228
# 4      1433423.375     2.974563e+05    1.559162e+05       29.340355
#
#    eeg_6_abs_median    eeg_6_std  eeg_6_abs_min  eeg_6_abs_max  \
# 0          2.908623  2598.026855   36513.625000    8121.781250
# 1          9.135956  2703.743896   12343.656250   22794.757812
# 2        101.357544  2488.236816   11962.589844    7408.435547
# 3          9.055824  2809.619141   20656.248047    8543.652344
# 4         45.762573  2534.850586   10990.937500   10515.437500
#
#    eeg_6_fd_petrosian  eeg_6_app_entropy  eeg_6_higuchi_fd  eeg_6_max_freq  \
# 0            1.019599           0.014191          1.317178        0.400000
# 1            1.015370           0.226703          1.174411        0.700000
# 2            1.011393           0.283410          1.194630        0.700000
# 3            1.009875           0.342949          1.200074        0.366667
# 4            1.010739           0.490191          1.301846        0.433333
#
#    eeg_6_max_spectrum  eeg_6_sum_spectrum  eeg_6_sum_delta  eeg_6_sum_theta  \
# 0           7763275.0         202492304.0      117418152.0       9539004.00
# 1          13016523.0         219306944.0      161533200.0       3920033.75
# 2          23528234.0         185739664.0      134303520.0       2855581.00
# 3          24746416.0         236818784.0      126340880.0       3746171.75
# 4          29561682.0         192764048.0      108151016.0       9573477.00
#
#    eeg_6_sum_alpha  eeg_6_sum_beta  eeg_7_abs_mean  eeg_7_abs_median  \
# 0     3.157190e+06    2.624072e+06        2.177756          0.177528
# 1     5.134787e+05    1.209727e+05       61.316540          6.029785
# 2     5.439401e+05    1.736128e+05       55.944511         10.172310
# 3     8.225998e+05    1.862090e+05       10.154667          8.171791
# 4     1.712971e+06    7.939999e+05        8.800878         56.665894
#
#        eeg_7_std  eeg_7_abs_min  eeg_7_abs_max  eeg_7_fd_petrosian  \
# 0  167560.750000   5.255950e+05   2.354940e+06            1.022962
# 1  157511.421875   1.506768e+06   5.922318e+05            1.017513
# 2     775.462891   3.270422e+03   6.469719e+03            1.019467
# 3   83287.539062   4.729199e+05   2.799326e+05            1.013477
# 4    1090.132935   5.060750e+03   4.975656e+03            1.013273
#
#    eeg_7_app_entropy  eeg_7_higuchi_fd  eeg_7_max_freq  eeg_7_max_spectrum  \
# 0           0.011610          1.289807        0.400000        3.208028e+10
# 1           0.067457          1.039459        0.333333        5.881455e+10
# 2           0.198334          1.372471        0.466667        1.460724e+06
# 3           0.081773          1.023973        0.366667        2.482227e+10
# 4           0.525455          1.318259        0.666667        3.756326e+06
#
#    eeg_7_sum_spectrum  eeg_7_sum_delta  eeg_7_sum_theta  eeg_7_sum_alpha  \
# 0        8.422984e+11     4.887117e+11     3.968538e+10     1.314612e+10
# 1        7.442954e+11     3.876225e+11     2.623445e+09     2.165159e+07
# 2        1.804028e+07     7.235718e+06     5.669928e+05     2.574918e+05
# 3        2.081044e+11     5.521945e+10     1.086434e+08     2.140821e+06
# 4        3.565169e+07     2.388400e+07     1.750078e+06     4.528802e+05
#
#    eeg_7_sum_beta  pulse_abs_mean  pulse_abs_median     pulse_std  \
# 0    1.094764e+10     7537.374023         12.306240  449755.87500
# 1    2.369768e+06    10970.662109          9.365090  312108.12500
# 2    2.059393e+05     6756.253418         10.330181  402651.46875
# 3    2.841267e+05     2368.146729         11.826424  349760.31250
# 4    1.842955e+05       42.876667         10.758974  382823.40625
#
#    pulse_abs_min  pulse_abs_max  pulse_fd_petrosian  pulse_app_entropy  \
# 0    3239698.250    1935694.625            1.008288           0.133832
# 1    1571443.375    1922978.375            1.008061           0.122787
# 2    3549563.500    1949519.250            1.008061           0.140544
# 3    2293820.250    1852200.750            1.008061           0.123940
# 4    3751390.000    2049451.500            1.008288           0.132744
#
#    pulse_higuchi_fd  pulse_max_freq  pulse_max_spectrum  pulse_sum_spectrum  \
# 0          1.676375             1.1        3.847899e+11        6.068410e+12
# 1          1.589549             0.6        2.401261e+11        2.922344e+12
# 2          1.674081             1.0        2.535419e+11        4.863847e+12
# 3          1.631561             0.7        2.101635e+11        3.669968e+12
# 4          1.641468             0.8        2.500640e+11        4.396613e+12
#
#    x_abs_mean  x_abs_median     x_std  x_abs_min  x_abs_max  x_fd_petrosian  \
# 0    0.350529      0.343190  0.020383   0.275146   0.404453        1.027353
# 1    0.391298      0.349783  0.070479   0.330948   0.632322        1.029886
# 2    0.687289      0.757896  0.291894   0.060969   1.083877        1.025866
# 3    0.151817      0.143681  0.031341   0.063542   0.300292        1.033436
# 4    0.408058      0.113374  0.390013   0.119260   1.161187        1.025012
#
#    x_app_entropy  x_higuchi_fd  x_max_freq  x_max_spectrum  x_sum_spectrum  \
# 0       0.292106      1.452881    0.033333        0.004876        0.012464
# 1       0.146592      1.364485    0.033333        0.085944        0.149019
# 2       0.324372      1.451437    0.033333        2.026439        2.556072
# 3       0.181315      1.410138    0.033333        0.004623        0.029468
# 4       0.188208      1.427892    0.033333        3.521251        4.563300
#
#    y_abs_mean  y_abs_median     y_std  y_abs_min  y_abs_max  y_fd_petrosian  \
# 0    0.092477      0.117236  0.050561   0.070726   0.154137        1.022867
# 1    0.128467      0.073640  0.094065   0.058779   0.426085        1.026079
# 2    0.024078      0.042186  0.271318   0.891660   0.548209        1.019837
# 3    0.005140      0.026418  0.073448   0.075320   0.307139        1.030096
# 4    0.084927      0.070625  0.101216   0.270750   0.391322        1.023727
#
#    y_app_entropy  y_higuchi_fd  y_max_freq  y_max_spectrum  y_sum_spectrum  \
# 0       0.221976      1.227075    0.033333        0.037067        0.076691
# 1       0.150873      1.300528    0.033333        0.155345        0.265446
# 2       0.462912      1.254144    0.033333        0.921316        2.208406
# 3       0.197422      1.498441    0.033333        0.053747        0.161837
# 4       0.426184      1.422877    0.200000        0.068239        0.307338
#
#    z_abs_mean  z_abs_median     z_std  z_abs_min  z_abs_max  z_fd_petrosian  \
# 0    0.934450      0.935650  0.005130   0.921782   0.956141        1.032813
# 1    0.909571      0.937507  0.047539   0.728916   0.942359        1.031144
# 2    0.375378      0.353569  0.522665   0.556950   0.989340        1.018310
# 3    0.979638      0.982871  0.012106   0.896752   1.004719        1.039395
# 4    0.789568      0.983055  0.245282   0.164203   1.013342        1.034886
#
#    z_app_entropy  z_higuchi_fd  z_max_freq  z_max_spectrum  z_sum_spectrum  \
# 0       0.362074      1.378305    0.033333        0.000220        0.000790
# 1       0.097321      1.187734    0.033333        0.038306        0.067797
# 2       0.197382      1.132256    0.033333        6.617780        8.195353
# 3       0.199147      1.682744    0.033333        0.000662        0.004397
# 4       0.187566      1.338848    0.033333        1.272376        1.804905
#
#    diff_eeg_1_2  diff_eeg_1_3  diff_eeg_1_4  diff_eeg_1_5  diff_eeg_1_6  \
# 0     4596007.0     8417847.0    11186173.0   6489601.000    6456558.50
# 1     8876900.0     8453449.0    13918117.0   6100392.000    6101809.00
# 2     3162709.8     3177547.8     3168938.0     30111.600      97558.17
# 3     3465082.5     3513582.8     6570933.0   3225712.500    3212343.80
# 4     9319208.0     9359706.0     9306871.0     42222.047     104158.31
#
#    diff_eeg_1_7  diff_eeg_2_3  diff_eeg_2_4  diff_eeg_2_5  diff_eeg_2_6  \
# 0  1.304677e+07     3822261.0   6590213.500     1893869.6     1860830.0
# 1  1.219981e+07    12314929.0   6099308.500     6149614.5     6139144.5
# 2  4.942146e+04     6339389.0     96550.125     3175011.5     3179191.8
# 3  6.451716e+06     2694969.5   3242713.500     1352737.1     1345762.2
# 4  6.167329e+04    18678598.0     85820.625     9336733.0     9342054.0
#
#    diff_eeg_2_7  diff_eeg_3_4  diff_eeg_3_5  diff_eeg_3_6  diff_eeg_3_7  \
# 0     8450889.0     2768869.5     1928391.6     1961431.4     4629048.5
# 1     8460455.0    13981560.0     6165732.5     6176174.0     8869064.0
# 2     3173337.5     6346061.5     3165153.2     3160903.5     3166929.2
# 3     3530070.0     4169650.8     1344134.5     1351397.2     3476281.0
# 4     9354362.0    18666458.0     9342057.0     9336800.0     9324443.0
#
#    diff_eeg_4_5  diff_eeg_4_6  diff_eeg_4_7  diff_eeg_5_6  diff_eeg_5_7  \
# 0     4696619.0     4729660.5     1860830.0     33053.223   6557171.500
# 1     8850256.0     8843190.0     6139144.5     83155.600   6099575.500
# 2     3181067.8     3187960.8     3179191.8     93580.570     27213.170
# 3     3477310.2     3491581.5     1345762.2    102392.420   3226050.000
# 4     9324445.0     9330519.0     9342054.0     85215.420     26606.807
#
#    diff_eeg_6_7
# 0   6590213.500
# 1   6099308.500
# 2     96550.125
# 3   3242713.500
# 4     85820.625

# %% [markdown]
# ## Feature space exploration

# %% [markdown]
# First step is to scale the features

# %%
scaler = preprocessing.StandardScaler()

# %%
x_train_scaled = pd.DataFrame(scaler.fit_transform(x_train), columns=x_train.columns)
x_test_scaled = pd.DataFrame(scaler.transform(x_test), columns=x_test.columns)

# %%
plot_continous_distribution(data=x_train_scaled, col='eeg_6_abs_mean', n_x=10)

# %% [markdown]
# Overall, the 'basic features' present an unevenly distribution across samples.

# %% [markdown]
# ## Removing obvious outliers

# %%
eegs = ['eeg_{}'.format(i) for i in range(1,8)]
x_scaled_clean = x_train_scaled
for eeg in  eegs:
    x_scaled_clean = x_scaled_clean.drop(x_scaled_clean[abs(x_scaled_clean[eeg + '_abs_mean']) > 4].index, inplace=False)

# %%
x_scaled_clean.shape
# Out:
# (24437, 170)

# %%
x_train_scaled.shape
# Out:
# (24688, 170)

# %% [markdown]
# ## Feature's correlation, importance and distribution VS sleep stages

# %%
x_train_scaled_ = x_train_scaled
x_train_scaled_['sleep_stage'] = train_labels['sleep_stage']

# %%
corr = x_train_scaled_.corr()

# %%
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(20, 20))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
fig = plt.figure(figsize=(20, 30))
for i in range(1,8):
    plt.subplot(7, 2, i)
    sns.boxplot(x='sleep_stage', y='eeg_{}_higuchi_fd'.format(i), data=x_train_scaled)

# %% [markdown]
# ## Model Training

# %%
clf = RandomForestClassifier(random_state=123)

# %%
# specify parameters and distributions to sample from
param_dist = {"n_estimators":[25, 50],
              "max_depth": [2, 5, None],
              "max_features": [None, 'sqrt', 0.2],
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

# %%
# run grid search
random_search = GridSearchCV(clf, 
                             param_grid=param_dist,
                             cv=5,
                             iid=False,
                             scoring='f1_weighted')

# %%
random_search.fit(x_train_scaled, train_labels['sleep_stage'])
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False, random_state=123,
#                                               verbose=0, warm_start=False),
#              iid=False, n_jobs=None,
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 5, None],
#                          'max_features': [None, 'sqrt', 0.2],
#                          'n_estimators': [25, 50]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='f1_weighted', verbose=0)

# %%
report(random_search.cv_results_, n_top=3)
# Out:
# Model with rank: 1
# Mean validation score: 0.650 (std: 0.017)
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 50}
#
# Model with rank: 2
# Mean validation score: 0.650 (std: 0.016)
# Parameters: {'bootstrap': False, 'criterion': 'entropy', 'max_depth': None, 'max_features': 0.2, 'n_estimators': 50}
#
# Model with rank: 3
# Mean validation score: 0.649 (std: 0.017)
# Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_depth': None, 'max_features': 0.2, 'n_estimators': 50}

# %%
top_n = 20
features_importances = pd.DataFrame({'Feature':x_train_scaled.columns, 'Importance':random_search.best_estimator_.feature_importances_})
features_importances.sort_values('Importance', ascending=False, inplace=True)
fig = plt.figure(figsize=(20,10))
sns.barplot(x='Importance', y='Feature', data=features_importances[0:20])

# %%
model = random_search.best_estimator_

# %%
train_predict = model.predict(x_train_scaled)

# %%
metrics.f1_score(y_true=train_labels['sleep_stage'], 
                 y_pred=train_predict,
                 average='weighted')
# Out:
# 1.0

# %% [markdown]
# ## Making predictions on the test set and export

# %%
results = random_search.best_estimator_.predict(x_test_scaled)
results_df = pd.DataFrame({'sleep_stage' : results})
results_df['index'] = results_df.index + 24688 # matching index with online test instance indexes
results_df = results_df[['index', 'sleep_stage']]

# %%
plot_categorical_distribution(results_df, col='sleep_stage', n_x=5)

# %%
results_df.to_csv('../predictions/2912_2_predictions.csv', header=True, index=False)

# %%
! head 2912_2_predictions.csv
# Out:
# index,sleep_stage
# 24688,0
# 24689,0
# 24690,0
# 24691,0
# 24692,0
# 24693,0
# 24694,0
# 24695,0
# 24696,0
